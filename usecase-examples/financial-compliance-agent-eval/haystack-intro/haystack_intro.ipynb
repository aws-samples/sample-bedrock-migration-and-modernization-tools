# %% [markdown]
# # Haystack Framework Introduction
#
# This notebook provides a comprehensive introduction to Haystack, demonstrating:
# 1. **Basic Haystack Pipeline**: Simple question-answering with minimal code
# 2. **MLflow Integration**: Experiment tracking and model management
# 3. **SageMaker Deployment**: Production-ready pipeline deployment

# %%
# %pip install -r requirements.txt
# Out:
# Collecting haystack-ai==2.14.3 (from -r requirements.txt (line 2))
#   Using cached haystack_ai-2.14.3-py3-none-any.whl.metadata (14 kB)
# Collecting amazon-bedrock-haystack==3.7.0 (from -r requirements.txt (line 3))
#   Using cached amazon_bedrock_haystack-3.7.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: mlflow<=3.1.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.22.0)
# Requirement already satisfied: boto3>=1.34.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.37.1)
# Requirement already satisfied: sagemaker>=2.245.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (2.245.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (2.3.3)
# Collecting haystack-experimental (from haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Downloading haystack_experimental-0.14.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (4.23.0)
# Collecting lazy-imports (from haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Downloading lazy_imports-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting more-itertools (from haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (1.26.4)
# Collecting openai>=1.56.1 (from haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Downloading openai-2.8.0-py3-none-any.whl.metadata (29 kB)
# Collecting posthog!=3.12.0 (from haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Downloading posthog-7.0.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (2.12.3)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0 in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.12/site-packages (from haystack-ai==2.14.3->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: aioboto3>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (14.1.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (0.71.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (7.1.0)
# Requirement already satisfied: fastapi<1 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (0.116.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.1.45)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (23.0.0)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (6.10.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (3.10.7)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (5.28.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (2.0.44)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: uvicorn<1 in /opt/conda/lib/python3.12/site-packages (from mlflow<=3.1.1->-r requirements.txt (line 6)) (0.35.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->-r requirements.txt (line 13)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.3.10)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (2.42.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.26.20)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /opt/conda/lib/python3.12/site-packages (from fastapi<1->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.48.0)
# Requirement already satisfied: blinker>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from Flask<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow<=3.1.1->-r requirements.txt (line 6)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow<=3.1.1->-r requirements.txt (line 6)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.12/site-packages (from graphene<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic->haystack-ai==2.14.3->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.12/site-packages (from pydantic->haystack-ai==2.14.3->-r requirements.txt (line 2)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from pydantic->haystack-ai==2.14.3->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil->haystack-ai==2.14.3->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->haystack-ai==2.14.3->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->haystack-ai==2.14.3->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->haystack-ai==2.14.3->-r requirements.txt (line 2)) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn<2->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn<2->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow<=3.1.1->-r requirements.txt (line 6)) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.12/site-packages (from starlette<0.49.0,>=0.40.0->fastapi<1->mlflow<=3.1.1->-r requirements.txt (line 6)) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi<1->mlflow<=3.1.1->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.12/site-packages (from uvicorn<1->mlflow<=3.1.1->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: botocore<1.38.0,>=1.37.1 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34.0->-r requirements.txt (line 9)) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34.0->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3>=1.34.0->-r requirements.txt (line 9)) (0.11.3)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (23.2.0)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: omegaconf<3,>=2.2 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.3.4)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (4.5.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (5.9.8)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.17 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (1.0.62)
# Requirement already satisfied: schema in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker>=2.245.0->-r requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.12/site-packages (from omegaconf<3,>=2.2->sagemaker>=2.245.0->-r requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.245.0->-r requirements.txt (line 10)) (14.2.0)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.245.0->-r requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema->haystack-ai==2.14.3->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema->haystack-ai==2.14.3->-r requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema->haystack-ai==2.14.3->-r requirements.txt (line 2)) (0.28.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.245.0->-r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.245.0->-r requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: aiobotocore==2.21.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (2.21.1)
# Requirement already satisfied: aiofiles>=23.2.1 in /opt/conda/lib/python3.12/site-packages (from aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /opt/conda/lib/python3.12/site-packages (from aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (6.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.12/site-packages (from aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->aiobotocore[boto3]==2.21.1->aioboto3>=14.0.0->amazon-bedrock-haystack==3.7.0->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.56.1->haystack-ai==2.14.3->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.56.1->haystack-ai==2.14.3->-r requirements.txt (line 2)) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai>=1.56.1->haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.56.1->haystack-ai==2.14.3->-r requirements.txt (line 2)) (1.0.9)
# Collecting backoff>=1.10.0 (from posthog!=3.12.0->haystack-ai==2.14.3->-r requirements.txt (line 2))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: ppft>=1.7.7 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.245.0->-r requirements.txt (line 10)) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker>=2.245.0->-r requirements.txt (line 10)) (0.70.18)
# Using cached haystack_ai-2.14.3-py3-none-any.whl (515 kB)
# Using cached amazon_bedrock_haystack-3.7.0-py3-none-any.whl (38 kB)
# Downloading openai-2.8.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.2 MB/s  0:00:00
# Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (361 kB)
# Downloading posthog-7.0.1-py3-none-any.whl (145 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading haystack_experimental-0.14.3-py3-none-any.whl (80 kB)
# Downloading lazy_imports-1.1.0-py3-none-any.whl (18 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Installing collected packages: more-itertools, lazy-imports, jiter, backoff, posthog, openai, haystack-experimental, haystack-ai, amazon-bedrock-haystack
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [amazon-bedrock-haystack]ck-ai]
# Successfully installed amazon-bedrock-haystack-3.7.0 backoff-2.2.1 haystack-ai-2.14.3 haystack-experimental-0.14.3 jiter-0.12.0 lazy-imports-1.1.0 more-itertools-10.8.0 openai-2.8.0 posthog-7.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
## Setup & Dependencies

import boto3
import mlflow
import sagemaker
import logging
from haystack import Pipeline
from haystack.components.builders import ChatPromptBuilder
from haystack.dataclasses import ChatMessage
from haystack_integrations.components.generators.amazon_bedrock import AmazonBedrockChatGenerator
from sagemaker.workflow.function_step import step
from sagemaker.workflow.pipeline import Pipeline as SageMakerPipeline
from sagemaker.workflow.parameters import ParameterString
import json
import time
from random import randint

bedrock_model="amazon.nova-lite-v1:0"
# This assumes you have MLFlow set up in SageMaker AI - copy/paste that server ARN here
tracking_server_arn="INSERT_MLFLOW_TRACKING_SERVER_ARN"
experiment_name=f"haystack-demo-{randint(1000,100000)}"

# %% [markdown]
# ## Part 1: Basic Haystack Demo
#
# Build a simple Haystack Q&A pipeline.

# %%
def qna_pipeline():
    pipeline = Pipeline()

    # Prompt Builder - formats the user question
    pipeline.add_component("prompt_builder", ChatPromptBuilder(
        template=[ChatMessage.from_user("Answer this question concisely: {{question}}")],
        required_variables=["question"]
    ))
    
    # LLM Generator - processes the prompt
    pipeline.add_component("llm", AmazonBedrockChatGenerator(model=bedrock_model))
    
    # Connect the components
    pipeline.connect("prompt_builder", "llm")

    return pipeline

# %%
# Test the pipeline
test_pipeline = qna_pipeline()
result = test_pipeline.run({"prompt_builder": {"question": "Who was the first president of the United States?"}})

print(result['llm']['replies'][0].text)
# Out:
# INFO:haystack.core.pipeline.pipeline:Running component prompt_builder
# INFO:haystack.core.pipeline.pipeline:Running component llm
# The first president of the United States was George Washington.

# %% [markdown]
# ## Part 2: MLflow Integration
#
# Now let's add experiment tracking to monitor our pipeline's performance and parameters.

# %%
def tracked_qna_pipeline(question: str, tracking_arn: str, experiment_name: str, model_id: str):
    mlflow.set_tracking_uri(tracking_arn)
    #if experiment_name:
        #print(f'experiment name is {experiment_name}; setting in mlflow.')
    mlflow.set_experiment(experiment_name)

    with mlflow.start_run() as run:
        # Log base parameters
        params = {"model": model_id, "question": question}
        mlflow.log_params(params)

        # Run pipeline
        pipeline = qna_pipeline()
        result = pipeline.run({"prompt_builder": {"question": question}})

        # Log results
        answer = result['llm']['replies'][0].text
        mlflow.log_metrics({"answer_length_chars": len(answer)})
        mlflow.log_text(answer, "answer.txt")

        print(f"🔬 Experiment logged with run_id: {run.info.run_id}")
        return answer, run.info.run_id

# %%
# Test the tracked pipeline
question = "Explain the benefits of ML orchestration frameworks in simple terms."
answer, run_id = tracked_qna_pipeline(question, experiment_name=experiment_name, tracking_arn=tracking_server_arn, model_id=bedrock_model)
print(f"Q: {question}")
print(f"A: {answer[:100]}...")
# Out:
# INFO:haystack.core.pipeline.pipeline:Running component prompt_builder
# INFO:haystack.core.pipeline.pipeline:Running component llm
# 🔬 Experiment logged with run_id: 6be884055e43430698f49a5da8a84882
# 🏃 View run stately-mole-102 at: https://us-east-1.experiments.sagemaker.aws/#/experiments/2/runs/6be884055e43430698f49a5da8a84882
# 🧪 View experiment at: https://us-east-1.experiments.sagemaker.aws/#/experiments/2
# Q: Explain the benefits of ML orchestration frameworks in simple terms.
# A: ML orchestration frameworks help manage and automate the complex tasks involved in machine learning ...

# %% [markdown]
# ## Part 3: SageMaker Pipeline Deployment
#
# Finally, let's deploy our Haystack pipeline to SageMaker for production use.

# %%
# Create SageMaker Pipeline object

# Define input parameters
question_param = ParameterString(name="Question")
model_param = ParameterString(name="ModelId")
tracking_server_arn_param = ParameterString(name="TrackingServerArn")
experiment_name_param = ParameterString(name="ExperimentName")

# Create one pipeline step
inference_step = step(
    tracked_qna_pipeline,
    name="haystack-qna-pipeline",
    keep_alive_period_in_seconds=300,
    dependencies="requirements-sagemaker.txt"
)(
    question=question_param,
    model_id=model_param,
    tracking_arn=tracking_server_arn_param,
    experiment_name=experiment_name_param
)

# Create the pipeline
sm_pipeline = SageMakerPipeline(
    name="haystack-intro-pipeline",
    parameters=[question_param, model_param, tracking_server_arn_param, experiment_name_param],
    steps=[inference_step],
    sagemaker_session=sagemaker.Session()
)

# %%
# Deploy and run the the pipeline
# This requires IAM permissions, and assumes we are running from a SageMaker Studio notebook

# Set desired logging level
for logger_name in ['sagemaker', 'sagemaker.remote_function', 'sagemaker.workflow', 'sagemaker.config']:
    logging.getLogger(logger_name).setLevel(logging.ERROR)

# deploy the pipeline
sm_pipeline.upsert(role_arn=sagemaker.get_execution_role())

execution = sm_pipeline.start(
    parameters={
        "Question": "How does the Haystack framework work?",
        "ModelId": bedrock_model,
        "TrackingServerArn": tracking_server_arn,
        "ExperimentName": experiment_name
    }
)
print(f"📊 Pipeline execution started: {execution.arn}")
# Out:
# 📊 Pipeline execution started: arn:aws:sagemaker:us-east-1:933591302813:pipeline/haystack-intro-pipeline/execution/enomc0s0ewre

# %% [markdown]
# ## Summary
#
# This notebook demonstrated three key aspects of building production LLM applications:
# - The use of Haystack to build a Q&A pipeline with just 3 components.
# - Automate experiment logging, with parameter and metric tracking, in MLFlow.
# - Deployment to SageMaker Pipelines for production-ready pipeline orchestration on scalable, managed infrastructre.
#
# For more complex examples, see:
# - `local_pipe/pipe_v2.ipynb` - Advanced RAG with tool routing
# - `sagemaker/main.ipynb` - Full MLOps pipeline with quality gates
